# %%
#数据生成
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import random
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus'] = False
# %matplotlib inline
# %config InlineBackend.figure_format='svg'

# %%
def CreateData(i):
    numbers=10000
    N=numbers*70//100
    class1 = np.random.randn(numbers//2,2) 
    #生成第一类25个2维特征数据 
    class2 = np.random.randn(numbers//2,2)+np.array([5,5])
    #生成第二类25个2维特征数据 
    label1 = [0]*(numbers//2)  #第一类标签0
    label2 = [1]*(numbers-numbers//2) #第二类标签1
    features = np.vstack((class1,class2))
    labels = label1+label2
    np.random.seed(i)
    np.random.shuffle(features)
    np.random.seed(i)
    np.random.shuffle(labels)
    return features,labels

# %%
#感知机训练算法
import numpy as np
import random
from matplotlib import pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus'] = False
# %matplotlib inline
# %config InlineBackend.figure_format='svg'



# 激活函数
def fun(n):
    if n > 0:
        return 1
    else:
        return 0

def training():
    # 样本点集
    trainDataX = train_data
    # 样本标签
    trainDataY = train_label
    global weight, bias
    for j in range(trainNum):
        # 从点集中随机取数
        i = random.randint(0, len(trainDataX) - 1)
        # 获取分类结果
        result = fun(np.dot(trainDataX[i], weight) + bias)
        # 若点分类正确,则后面代码不需要执行
        if result == trainDataY[i]: 
            continue
        # 更新权重
        # 等价于下面两个式子
        weight = weight + np.dot((trainDataY[i] - result), trainDataX[i]) \
                 * learnRate
        # weight[0] = weight[0] + (trainDataY[i] - result) * \
        #             trainDataX[i][0] * learnRate
        # weight[1] = weight[1] + (trainDataY[i] - result) * \
        #             trainDataX[i][1] * learnRate
        #print(str(result) + '    ' + str(trainDataY[i]))
        # 更新偏移量
        bias = bias + (trainDataY[i] - result) * learnRate
        #print("Update weight and bias: ")
    #print("训练完成,weight: ", weight, "bias ", bias)
    
    
def test_ganzhiji():
    # 样本点集
    trainDataX = train_data
    # 样本标签
    trainDataY = train_label
    training()
    pred_label = []
    for i in range(test_data.shape[0]):
        pred = fun(weight[0] * test_data[i][0] + weight[1] * test_data[i][1] + bias)
        pred_label.append(pred)
    
    wrong_data = []
    for i in range(len(test_label)):
        if (pred_label[i] != test_label[i]):
            wrong_data.append(test_data[i])
    accuracy = (len(test_data)-len(wrong_data))/len(test_data)
    #print("在测试集的准确率为：", accuracy)
    return accuracy

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

def test_beiyesi():
    # 创建模型并拟合数据
    model = GaussianNB()
    model.fit(train_data, train_label)
    
    # 预测新数据
    pred_label = model.predict(test_data)
    
    # 计算准确率
    accuracy = accuracy_score(np.array(test_label), pred_label)
    return accuracy

# %%
from sklearn import svm
from sklearn.metrics import accuracy_score

def test_SVM():

    # 创建模型并拟合数据
    model = svm.SVC(kernel='linear')
    model.fit(train_data, train_label)

    # 预测新数据
    pred_label = model.predict(test_data)

    # 计算准确率
    accuracy = accuracy_score(np.array(test_label), pred_label)
    return accuracy

# %%
average_ganzhiji = 0
average_beiyesi = 0
average_SVM = 0
for i in range (100):
    numbers=10000
    N=numbers*70//100
    features,labels = CreateData(i)
    train_data=features[:N]
    train_label=labels[:N]
    test_data=features[N:]
    test_label=labels[N:]
    #print(features)
    trainDataX = train_data
    # 样本标签
    trainDataY = train_label
    # 权重
    weight = [0, 0]
    # 偏置量
    bias = 0
    # 学习速率,控制每一步调整权的幅度
    learnRate = 0.2
    # 输入最大训练次数
    trainNum =500
    average_ganzhiji = average_ganzhiji + test_ganzhiji()
    average_beiyesi = average_beiyesi + test_beiyesi()
    average_SVM = average_SVM + test_SVM()
print("感知机的平均准确率是：",average_ganzhiji,"%")
print("贝叶斯的平均准确率是：",average_beiyesi,"%")
print("SVM的平均准确率是：",average_SVM,"%")
# Out:
# 感知机的平均准确率是： 99.32166666666667 %
# 贝叶斯的平均准确率是： 99.9803333333334 %
# SVM的平均准确率是： 99.97700000000009 %
